# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
dataset=[11,10,12,14,12,15,14,13,15,102,10,13,12,14,12,108,12,11,14,13,10,15,12,10]
outliers=[]
def detect_outliers(data):
    threshold=3
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z_score= (i - mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers
outlier_pt=detect_outliers(dataset)
outlier_pt
# Out:
# [102, 108]

# %%
sorted(dataset)
# Out:
# [10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  102,
#  108]

# %%
quantile1,quantile3 = np.percentile(dataset,[25,75])

# %%
print(quantile1,quantile3)
# Out:
# 11.75 14.0

# %%
iqr_value=quantile3-quantile1
print(iqr_value)
# Out:
# 2.25

# %%
lower_value = quantile1 -(1.5 * iqr_value)
upper_value = quantile3 +(1.5 * iqr_value)
print(lower_value,upper_value)
# Out:
# 8.375 17.375

# %%
# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(range(len(dataset)), dataset, color='b', label='Data Points')
# Out:
# <BarContainer object of 24 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
dataset=[11,10,12,14,12,15,14,13,15,102,10,13,12,14,12,108,12,11,14,13,10,15,12,10]
outliers=[]
def detect_outliers(data):
    threshold=3
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z_score= (i - mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers
outlier_pt=detect_outliers(dataset)
outlier_pt
plt.bar(range(len(dataset)), dataset, color='b', label='Data Points')
for i, data_point in enumerate(dataset):
    if data_point in outlier_pt:
        plt.bar(i, data_point, color='r')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
dataset=[11,10,12,14,12,15,14,13,15,102,10,13,12,14,12,108,12,11,14,13,10,15,12,10]
outliers=[]
def detect_outliers(data):
    threshold=3
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z_score= (i - mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers
outlier_pt=detect_outliers(dataset)
outlier_pt
plt.scatter(range(len(dataset)), dataset, c='b', label='Data Points')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 10, 15, 12, 10]
outliers = []

def detect_outliers(data):
    threshold = 3
    mean = np.mean(data)
    std = np.std(data)

    for i in data:
        z_score = (i - mean) / std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

outlier_pts = detect_outliers(dataset)
# Create a boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(dataset, vert=False, sym='ro', widths=0.7)
plt.title('Boxplot with Outliers Highlighted')
plt.xlabel('Data Points')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')
