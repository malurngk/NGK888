# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("C:/Users/pradeep/Downloads/Divi-Engine-WooCommerce-Sample-Products.csv")

# %%
df.head()
# Out:
#    ID       Type  SKU                                  Name  Published  \
# 0  66     simple  NaN     Divi Engine String Bag (Big Logo)          1
# 1  70     simple  NaN  Divi Engine String Bag (Small Logos)          1
# 2  74   variable  NaN                         Brand Buttons          1
# 3  75  variation  NaN                  Brand Buttons - Divi          1
# 4  76  variation  NaN           Brand Buttons - Divi Engine          1
#
#    Is featured? Visibility in catalog  \
# 0             0               visible
# 1             0               visible
# 2             0               visible
# 3             0               visible
# 4             0               visible
#
#                                    Short description  \
# 0  This fashionable string bag is made of 100% co...
# 1  This fashionable string bag is made of 100% co...
# 2  Represent your favorite CMS, eCommerce Platfor...
# 3                                                NaN
# ...

# %%
df.ID.describe()
# Out:
# count     68.000000
# mean     124.382353
# std       28.932773
# min       66.000000
# 25%      100.750000
# 50%      126.000000
# 75%      147.250000
# max      171.000000
# Name: ID, dtype: float64

# %%
df['ID'].hist()
# Out:
# <Axes: >

# %%
df['ID_cat'] = pd.cut(x=df['ID'],bins = 5,labels = ['count','mean ','std','min','max'])

# %%
df['ID_cat'].value_counts()
# Out:
# min      17
# std      15
# mean     14
# max      14
# count     8
# Name: ID_cat, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
def draw_barplot(x):
    s = x.value_counts()
    plt.bar(s.index, s.values)

# %%
draw_barplot(df['ID_cat'])

# %%
df.head()
# Out:
#    ID       Type  SKU                                  Name  Published  \
# 0  66     simple  NaN     Divi Engine String Bag (Big Logo)          1
# 1  70     simple  NaN  Divi Engine String Bag (Small Logos)          1
# 2  74   variable  NaN                         Brand Buttons          1
# 3  75  variation  NaN                  Brand Buttons - Divi          1
# 4  76  variation  NaN           Brand Buttons - Divi Engine          1
#
#    Is featured? Visibility in catalog  \
# 0             0               visible
# 1             0               visible
# 2             0               visible
# 3             0               visible
# 4             0               visible
#
#                                    Short description  \
# 0  This fashionable string bag is made of 100% co...
# 1  This fashionable string bag is made of 100% co...
# 2  Represent your favorite CMS, eCommerce Platfor...
# 3                                                NaN
# ...
