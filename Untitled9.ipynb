# %%
import matplotlib.pyplot as plt
ename = ['roshan','amar','ashwini','lohith']
salary = [15000,30000,15000,20000]
plt.figure(figsize=(6,6))
plt.pie(salary , labels=ename, autopct='%2.1f%%', startangle=140)
plt.title("pie chart")
plt.show()

# %% [markdown]
# ###
